# %% [markdown]
# ## Task 5: Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Importing necessary libraires

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading data

# %%
df=pd.read_csv('../data/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## display first five rows

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## display first five rows

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ## Information of the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## shape of the data

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# ## Statistical information

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## Datatypes

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ## columns

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# Categorical value counts
print(df['Sex'].value_counts())
print(df['Name'].value_counts())
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64
# Name
# Braund, Mr. Owen Harris                     1
# Boulos, Mr. Hanna                           1
# Frolicher-Stehli, Mr. Maxmillian            1
# Gilinski, Mr. Eliezer                       1
# Murdlin, Mr. Joseph                         1
#                                            ..
# Kelly, Miss. Anna Katherine "Annie Kate"    1
# McCoy, Mr. Bernard                          1
# Johnson, Mr. William Cahoone Jr             1
# Keane, Miss. Nora A                         1
# Dooley, Mr. Patrick                         1
# Name: count, Length: 891, dtype: int64

# %% [markdown]
# ## Missing values

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#there are no duplicates

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#there are nulls in the data

# %% [markdown]
# ## Handling nulls

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)
df['Cabin'].fillna('Unknown', inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# ## outliers

# %% [markdown]
# ## Boxplots – Outlier Visual Check

# %%
for col in ['Age', 'SibSp', 'Parch', 'Fare']:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=df[col], color='lightgreen')
    plt.title(f"Boxplot of {col}")
    plt.show()

# %% [markdown]
# ## By statistical method -IQR

# %%
# Select all numeric columns
num_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Loop through each numeric column and count outliers
for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    print(f"{col}: {len(outliers)} outliers")
# Out:
# PassengerId: 0 outliers
# Survived: 0 outliers
# Pclass: 0 outliers
# Age: 66 outliers
# SibSp: 46 outliers
# Parch: 213 outliers
# Fare: 116 outliers

# %% [markdown]
# Outlier Analysis
# PassengerId → 0 outliers (this is just a unique ID, not relevant for outlier checks).
#
# Survived → 0 outliers (binary column: 0 or 1).
#
# Pclass → 0 outliers (categorical numeric: 1, 2, 3).
#
# Age → 66 outliers — mostly older passengers above ~65 years or very young ages like <1 year (can be genuine, so keep for analysis).
#
# SibSp → 46 outliers — large numbers of siblings/spouses traveling together (rare but valid).
#
# Parch → 213 outliers — many passengers had 0–3 parents/children, but high numbers here are rare; still can be real.
#
# Fare → 116 outliers — high fares for 1st class and private cabins (valid but will skew charts if not handled).

# %% [markdown]
# ## Handling outliers

# %%
import numpy as np

for col in ['Age', 'SibSp', 'Parch', 'Fare']:
    # Calculate bounds
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Count outliers before handling
    before_outliers = ((df[col] < lower_bound) | (df[col] > upper_bound)).sum()
    
    # Cap the outliers
    df[col] = np.where(df[col] > upper_bound, upper_bound,
                       np.where(df[col] < lower_bound, lower_bound, df[col]))
    
    # Count outliers after handling
    after_outliers = ((df[col] < lower_bound) | (df[col] > upper_bound)).sum()
    
    print(f"{col}: Before handling = {before_outliers}, After handling = {after_outliers}")
# Out:
# Age: Before handling = 66, After handling = 0
# SibSp: Before handling = 46, After handling = 0
# Parch: Before handling = 213, After handling = 0
# Fare: Before handling = 116, After handling = 0

# %%
##now there are no outliers

# %% [markdown]
# # Visuals

# %% [markdown]
#  ## Pairplot – Relationships & Trends

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select relevant columns for pairplot
sns.pairplot(df[['Age', 'Fare', 'Pclass', 'Survived']], hue='Survived', diag_kind='kde')
plt.suptitle("Pairplot: Relationships Between Key Features", y=1.02)
plt.show()

# %%
# Observation:
# - Survived passengers generally had higher fares and were often in higher classes.
# - Age distribution shows no strong separation between survivors and non-survivors.

# %% [markdown]
#  ## Heatmap – Correlation Matrix

# %%
corr = df.select_dtypes(include=['int64', 'float64']).corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Histograms – Distribution of Numeric Columns

# %%
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

df[num_cols].hist(bins=20, figsize=(12, 10), color='skyblue', edgecolor='black')
plt.suptitle("Histograms of Numeric Features", y=1.02)
plt.show()

# %%
# Observation:
# - Most passengers paid low fares; only a few paid high fares.
# - Majority were young to middle-aged, with some children and elderly passengers.

# %% [markdown]
# ## Scatterplots – Key Relationships

# %%
# Age vs Fare colored by survival
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Age', y='Fare', hue='Survived', data=df, palette='Set1')
plt.title("Age vs Fare by Survival")
plt.show()

# %% [markdown]
# ## Countplots – Categorical Insights

# %%
# Survival by Sex
sns.countplot(x='Sex', hue='Survived', data=df, palette='pastel')
plt.title("Survival Count by Gender")
plt.show()

# Observation:
# - Females had a higher survival rate than males.

# Survival by Pclass
sns.countplot(x='Pclass', hue='Survived', data=df, palette='muted')
plt.title("Survival Count by Passenger Class")
plt.show()
